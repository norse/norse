# %%
import pandas as pd

# %%
lif_benchmarks = !ls *_lif.py

# %%
for benchmark in lif_benchmarks:
    # !python3 $benchmark --device=cuda
# Out:
# size': 2, 'duration': 0.025006771087646484, 'dt': 0.001, 'time_steps': 100, 'device': 'cuda'}
# I0601 09:18:22.660236 140143704733504 norse_lif.py:92] {'label': 'lif_feed_forward', 'input_features': 4250, 'output_features': 4250, 'batch_size': 2, 'duration': 0.024890661239624023, 'dt': 0.001, 'time_steps': 100, 'device': 'cuda'}
# I0601 09:18:22.799728 140143704733504 norse_lif.py:92] {'label': 'lif_feed_forward', 'input_features': 4500, 'output_features': 4500, 'batch_size': 2, 'duration': 0.025974035263061523, 'dt': 0.001, 'time_steps': 100, 'device': 'cuda'}
# I0601 09:18:22.954772 140143704733504 norse_lif.py:92] {'label': 'lif_feed_forward', 'input_features': 4750, 'output_features': 4750, 'batch_size': 2, 'duration': 0.029207229614257812, 'dt': 0.001, 'time_steps': 100, 'device': 'cuda'}
# ...

# %%
bindsnet_df = pd.read_csv("b.csv")
norse_df = pd.read_csv("n.csv")
pysnn_df = pd.read_csv("p.csv")

# %%
ax = bindsnet_df[bindsnet_df["batch_size"] == 4].plot(x = "input_features", y="duration", label="BindsNET", logy=True)
norse_df[norse_df["batch_size"] == 4].plot(x = "input_features", y="duration", ax=ax, label="Norse")
pysnn_df[pysnn_df["batch_size"] == 4].plot(x = "input_features", y="duration", ax=ax, label="PySNN")
